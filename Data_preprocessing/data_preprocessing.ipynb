# %% [markdown]
# # Data Processing
#
# The goal is to create a data set with a single (clean) row of values for each date.  If you have 'good' values from all three weather stations, you should use the average of those values; however, you need to be careful not to let the 'bad' data mess up your estimates.  E.g. if there's a missing value, you want to take the average of the two good values (as opposed to adding the two good values and then dividing by three); if there's a clearly mistaken measurement, you likewise don't want to include that in the average.
#
# Note that you need to do this for each of the three temperature columns, TMIN, TMAX, and TAVG.  Once you have created this cleaned version of the data set, you can generate a few simple plots to look at the resulting data, including a line graph that shows how the temperatures (monthly low, high, and average) have evolved over the time period included in the data, and a box plot showing the distribution of the data from each of those three columns.

# %%
import pandas as pd # database loading and manipulation library
import numpy as np # numeric python lybrary
import matplotlib.pyplot as plt # plotting and graphing library
#%matplotlib notebook # tell the plotting library we're running an interactive notebook

# %%
data = pd.read_csv('temperaturesRaw.csv', parse_dates=['DATE'])

# %%
data.head()
# Out:
#        STATION                                       NAME  LATITUDE  \
# 0  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 1  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 2  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 3  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 4  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
#
#    LONGITUDE  ELEVATION       DATE  AWND AWND_ATTRIBUTES  PRCP  \
# 0  -75.22678        3.0 1948-01-01   NaN             NaN  4.69
# 1  -75.22678        3.0 1948-02-01   NaN             NaN  2.84
# 2  -75.22678        3.0 1948-03-01   NaN             NaN  3.76
# 3  -75.22678        3.0 1948-04-01   NaN             NaN  3.93
# 4  -75.22678        3.0 1948-05-01   NaN             NaN  7.41
#
#   PRCP_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN  \
# 0            ,,,X  25.9              ,X  32.8            ,,,X  19.1
# 1            ,,,X  31.8              ,X  40.2            ,,,X  23.3
# 2            ,,,X  43.8              ,X  54.5            ,,,X  33.2
# 3            ,,,X  52.0              ,X  62.2            ,,,X  41.7
# 4            ,,,0  61.9              ,0  71.3            ,,,0  52.5
#
#   TMIN_ATTRIBUTES
# 0            ,,,X
# 1            ,,,X
# 2            ,,,X
# 3            ,,,X
# 4            ,,,0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3399 entries, 0 to 3398
# Data columns (total 16 columns):
# STATION            3399 non-null object
# NAME               3399 non-null object
# LATITUDE           3399 non-null float64
# LONGITUDE          3399 non-null float64
# ELEVATION          3399 non-null float64
# DATE               3399 non-null datetime64[ns]
# AWND               409 non-null float64
# AWND_ATTRIBUTES    409 non-null object
# PRCP               3331 non-null float64
# PRCP_ATTRIBUTES    3331 non-null object
# TAVG               3261 non-null float64
# TAVG_ATTRIBUTES    3290 non-null object
# TMAX               3285 non-null float64
# TMAX_ATTRIBUTES    3315 non-null object
# TMIN               3307 non-null float64
# TMIN_ATTRIBUTES    3336 non-null object
# dtypes: datetime64[ns](1), float64(8), object(7)
# memory usage: 425.0+ KB

# %%
data['PRCP'].max()
# Out:
# 19.31

# %% [markdown]
# ### TimeDate objects are flexible
# You can treat them as units, but its also easy to pull out the components using properties (see https://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components)

# %%
data['DATE'][0]
# Out:
# Timestamp('1948-01-01 00:00:00')

# %%
print('first row year is', data['DATE'][0].year, 'first row month is', data['DATE'][0].month)
# Out:
# first row year is 1948 first row month is 1

# %% [markdown]
# According to the NOAA documentation, AWND is the average wind speed, PRCP is the total precipitation, TAVG is the monthly average temperature, TMIN and TMAX are the monthly min and max temperatures.  The ATTRIBUTES columns give extra information about the associated column.  Full documentation can be found at https://www1.ncdc.noaa.gov/pub/data/cdo/documentation/gsom-gsoy_documentation.pdf but for this assignment it's safe to just ignore the ATTRIBUTES columns.
#
# It's fine to drop columns that you're not using for your analysis, particularly if they seem to be distracting and/or not really meaningful in the conjoined version of the data.

# %% [markdown]
# # Sort
# sorting the data by date

# %%
data.sort_values(by='DATE', ascending=True)
# Out:
#           STATION                                       NAME  LATITUDE  \
# 2198  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 841   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2199  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 842   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 843   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 844   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 845   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 846   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 847   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 848   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 849   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 850   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 851   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 852   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2200  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 2201  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 853   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2202  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 854   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 855   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2203  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 856   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2204  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 2205  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 857   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2206  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 858   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2207  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 859   USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 2208  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# ...           ...                                        ...       ...
# 827   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 2193  USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 3388  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 2194  USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 828   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 2195  USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 3389  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 829   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 2196  USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 3390  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 830   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 2197  USC00369464                   WEST CHESTER 2 NW, PA US  39.97080
# 3391  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 831   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 832   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 3392  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 833   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 3393  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 3394  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 834   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 835   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 3395  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 836   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 3396  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 3397  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 837   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 838   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 3398  USC00366927                    PHOENIXVILLE 1 E, PA US  40.12000
# 839   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
# 840   USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  39.87327
#
#       LONGITUDE  ELEVATION       DATE  AWND AWND_ATTRIBUTES   PRCP  \
# 2198  -75.50110       32.0 1893-01-01   NaN             NaN   2.62
# 841   -75.63500      114.3 1893-01-01   NaN             NaN    NaN
# 2199  -75.50110       32.0 1893-02-01   NaN             NaN   5.54
# 842   -75.63500      114.3 1893-02-01   NaN             NaN   6.13
# 843   -75.63500      114.3 1893-04-01   NaN             NaN   5.02
# 844   -75.63500      114.3 1893-05-01   NaN             NaN   4.18
# 845   -75.63500      114.3 1893-06-01   NaN             NaN   2.59
# 846   -75.63500      114.3 1893-07-01   NaN             NaN    NaN
# 847   -75.63500      114.3 1893-08-01   NaN             NaN   3.65
# 848   -75.63500      114.3 1893-09-01   NaN             NaN   2.58
# 849   -75.63500      114.3 1893-10-01   NaN             NaN    NaN
# 850   -75.63500      114.3 1893-11-01   NaN             NaN    NaN
# 851   -75.63500      114.3 1893-12-01   NaN             NaN    NaN
# 852   -75.63500      114.3 1894-01-01   NaN             NaN   1.60
# 2200  -75.50110       32.0 1894-01-01   NaN             NaN   2.00
# 2201  -75.50110       32.0 1894-02-01   NaN             NaN   4.00
# 853   -75.63500      114.3 1894-02-01   NaN             NaN    NaN
# 2202  -75.50110       32.0 1894-03-01   NaN             NaN   1.77
# 854   -75.63500      114.3 1894-03-01   NaN             NaN   1.68
# 855   -75.63500      114.3 1894-04-01   NaN             NaN    NaN
# 2203  -75.50110       32.0 1894-04-01   NaN             NaN   2.34
# 856   -75.63500      114.3 1894-05-01   NaN             NaN    NaN
# 2204  -75.50110       32.0 1894-05-01   NaN             NaN  10.49
# 2205  -75.50110       32.0 1894-06-01   NaN             NaN   5.41
# 857   -75.63500      114.3 1894-06-01   NaN             NaN    NaN
# 2206  -75.50110       32.0 1894-07-01   NaN             NaN   3.09
# 858   -75.63500      114.3 1894-07-01   NaN             NaN    NaN
# 2207  -75.50110       32.0 1894-08-01   NaN             NaN   1.45
# 859   -75.63500      114.3 1894-08-01   NaN             NaN   1.86
# 2208  -75.50110       32.0 1894-09-01   NaN             NaN   6.81
# ...         ...        ...        ...   ...             ...    ...
# 827   -75.22678        3.0 2016-12-01  10.1              ,W   2.72
# 2193  -75.63500      114.3 2016-12-01   NaN             NaN   5.04
# 3388  -75.50110       32.0 2017-01-01   NaN             NaN   3.08
# 2194  -75.63500      114.3 2017-01-01   NaN             NaN   3.35
# 828   -75.22678        3.0 2017-01-01   9.6              ,W   2.91
# 2195  -75.63500      114.3 2017-02-01   NaN             NaN   1.90
# 3389  -75.50110       32.0 2017-02-01   NaN             NaN   1.37
# 829   -75.22678        3.0 2017-02-01  10.3              ,W   1.30
# 2196  -75.63500      114.3 2017-03-01   NaN             NaN   3.58
# 3390  -75.50110       32.0 2017-03-01   NaN             NaN   2.49
# 830   -75.22678        3.0 2017-03-01  12.3              ,W   4.26
# 2197  -75.63500      114.3 2017-04-01   NaN             NaN   5.22
# 3391  -75.50110       32.0 2017-04-01   NaN             NaN   2.96
# 831   -75.22678        3.0 2017-04-01   9.4              ,W   3.15
# 832   -75.22678        3.0 2017-05-01   9.8              ,W   6.33
# 3392  -75.50110       32.0 2017-05-01   NaN             NaN   3.75
# 833   -75.22678        3.0 2017-06-01   8.9              ,W   1.86
# 3393  -75.50110       32.0 2017-06-01   NaN             NaN   4.56
# 3394  -75.50110       32.0 2017-07-01   NaN             NaN   3.11
# 834   -75.22678        3.0 2017-07-01   7.8              ,W   5.36
# 835   -75.22678        3.0 2017-08-01   6.9              ,W   6.05
# 3395  -75.50110       32.0 2017-08-01   NaN             NaN   3.46
# 836   -75.22678        3.0 2017-09-01   8.1              ,W   3.86
# 3396  -75.50110       32.0 2017-09-01   NaN             NaN   1.03
# 3397  -75.50110       32.0 2017-10-01   NaN             NaN   3.88
# 837   -75.22678        3.0 2017-10-01   8.3              ,W   3.67
# 838   -75.22678        3.0 2017-11-01   8.9              ,W   1.31
# 3398  -75.50110       32.0 2017-11-01   NaN             NaN   0.76
# 839   -75.22678        3.0 2017-12-01   8.9              ,W   1.31
# 840   -75.22678        3.0 2018-01-01  10.1              ,W   2.86
#
#      PRCP_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES   TMIN  \
# 2198            ,,,6  21.1              ,6  30.0            ,,,6   12.3
# 841              NaN  21.3              ,6  28.5            ,,,6   14.1
# 2199           1,,,6  30.9              ,6  38.7            ,,,6   23.2
# 842             ,,,6  30.2             1,6  38.0           1,,,6  -84.7
# 843             ,,,6  51.7             5,6  61.7           2,,,6  -68.2
# 844             ,,,6  59.5              ,6  69.0            ,,,6   50.0
# 845             ,,,6  70.8             1,6  79.7            ,,,6   61.9
# 846              NaN  74.4              ,6  83.5            ,,,6   65.3
# 847             ,,,6  73.7              ,6  83.0            ,,,6   64.4
# 848             ,,,6  64.1              ,6  72.9            ,,,6   55.3
# 849              NaN  56.1              ,6  65.5            ,,,6   46.8
# 850              NaN  41.7              ,6  49.2            ,,,6   34.2
# 851              NaN  35.4              ,6  44.0            ,,,6  134.9
# 852             ,,,6  34.1              ,6   NaN            ,,,6   27.7
# 2200            ,,,6  34.2             2,6  41.8           1,,,6   26.6
# 2201            ,,,6  30.1              ,6  38.0            ,,,6   22.2
# 853              NaN  29.6              ,6  37.4            ,,,6    NaN
# 2202            ,,,6  45.0              ,6  55.6            ,,,6   34.3
# 854             ,,,6  44.9              ,6  54.2            ,,,6   35.6
# 855              NaN  50.1             1,6  59.7           1,,,6   40.5
# 2203            ,,,6  50.7              ,6  60.5            ,,,6   40.8
# 856              NaN  62.3              ,6  71.4            ,,,6   53.2
# 2204            ,,,6  61.6              ,6  72.2            ,,,6   51.0
# 2205           1,,,6  71.5              ,6  81.8            ,,,6   61.1
# 857              NaN  71.2              ,6  81.0            ,,,6   61.4
# 2206            ,,,6  75.2              ,6  85.4            ,,,6   65.1
# 858              NaN  75.7              ,6  84.5            ,,,6   66.8
# 2207            ,,,6  71.4              ,6  81.7            ,,,6   61.2
# 859             ,,,6  70.9              ,6  79.3            ,,,6   62.4
# 2208           1,,,6  68.0             1,6  77.3            ,,,6   58.6
# ...              ...   ...             ...   ...             ...    ...
# 827             ,,,W  38.9              ,W  45.6            ,,,W   32.1
# 2193            ,,,7  35.1              ,7  45.0            ,,,7   25.2
# 3388           3,,,7  36.0             2,7  43.2           1,,,7   28.9
# 2194            ,,,7  34.6              ,7  42.6            ,,,7    NaN
# 828             ,,,W  38.5              ,W  44.3            ,,,W   32.7
# 2195            ,,,7  39.0              ,7  51.2            ,,,7   26.8
# 3389           1,,,7  41.3             1,7  52.2           1,,,7   30.4
# 829             ,,,W   NaN              ,W  53.5            ,,,W   34.9
# 2196           1,,,7  38.0              ,7  49.3            ,,,7   26.7
# 3390           3,,,7  40.5              ,7  49.8            ,,,7   31.1
# 830             ,,,W  42.1              ,W  50.6            ,,,W   33.6
# 2197            ,,,7  56.5              ,7  67.8            ,,,7   45.1
# 3391            ,,,7  58.2              ,7  69.1            ,,,7   47.2
# 831             ,,,W  59.5              ,W  69.1            ,,,W   49.8
# 832             ,,,W  63.1              ,W  71.6            ,,,W   54.6
# 3392           2,,,7  61.2              ,7  71.0            ,,,7   51.5
# 833             ,,,W  74.6              ,W  84.1            ,,,W   65.2
# 3393           2,,,7  72.4             2,7  83.9           2,,,7   60.9
# 3394           2,,,7  77.4              ,7  87.1            ,,,7   67.7
# 834             ,,,W  79.3              ,W  87.4            ,,,W   71.1
# 835             ,,,W  75.3              ,W  83.2            ,,,W   67.3
# 3395            ,,,7  73.2              ,7  83.7            ,,,7   62.7
# 836             ,,,W  71.4              ,W  79.6            ,,,W   63.2
# 3396           1,,,7  69.2             1,7  80.5           1,,,7   57.9
# 3397            ,,,7  61.0              ,7  72.1            ,,,7   49.9
# 837             ,,,W  64.1              ,W  72.4            ,,,W   55.7
# 838             ,,,W  47.5              ,W  56.4            ,,,W   38.6
# 3398           3,,,7  44.1             3,7  55.9           3,,,7   32.4
# 839             ,,,W  36.1              ,W  42.6            ,,,W   29.6
# 840             ,,,W  32.8              ,W  41.4            ,,,W   24.3
#
#      TMIN_ATTRIBUTES
# 2198            ,,,6
# 841             ,,,6
# 2199            ,,,6
# 842            1,,,6
# 843            3,,,6
# 844             ,,,6
# 845            1,,,6
# 846             ,,,6
# 847             ,,,6
# 848             ,,,6
# 849             ,,,6
# 850             ,,,6
# 851             ,,,6
# 852             ,,,6
# 2200           1,,,6
# 2201            ,,,6
# 853             ,,,6
# 2202            ,,,6
# 854             ,,,6
# 855             ,,,6
# 2203            ,,,6
# 856             ,,,6
# 2204            ,,,6
# 2205            ,,,6
# 857             ,,,6
# 2206            ,,,6
# 858             ,,,6
# 2207            ,,,6
# 859             ,,,6
# 2208           1,,,6
# ...              ...
# 827             ,,,W
# 2193            ,,,7
# 3388           2,,,7
# 2194            ,,,7
# 828             ,,,W
# 2195            ,,,7
# 3389           1,,,7
# 829             ,,,W
# 2196            ,,,7
# 3390            ,,,7
# 830             ,,,W
# 2197            ,,,7
# 3391            ,,,7
# 831             ,,,W
# 832             ,,,W
# 3392            ,,,7
# 833             ,,,W
# 3393           2,,,7
# 3394            ,,,7
# 834             ,,,W
# 835             ,,,W
# 3395            ,,,7
# 836             ,,,W
# 3396           1,,,7
# 3397            ,,,7
# 837             ,,,W
# 838             ,,,W
# 3398           3,,,7
# 839             ,,,W
# 840             ,,,W
#
# [3399 rows x 16 columns]

# %% [markdown]
# Now we need to calculate total sum of readings for each date by different stations and
# their calculated average.
# For this we need to calculate the sum of temperature readings on each month made by different stations. Looking at the description of data, AWND values are only present 409 of the times, missing almost 88% of the time
# Lets see if average wind speed affects the temperature readings

# %%
data['AWND'].unique()
# Out:
# array([ nan,  6.3,  9.8, 11.4,  8.3,  8.1,  7.4,  7.2,  8.9, 10.3, 11.2,
#         9.2,  7.8,  9.6, 10.1,  8.5,  9.4, 10.5,  8.7, 11.9, 11. , 12.8,
#        10.7, 12.5, 13. , 13.6, 11.6,  6.7,  6.9,  5.8,  7.6, 13.4, 12.3,
#        12.1,  6.5])

# %% [markdown]
# Make a scatterplot for AWND and TAVG and see if we can find some relation

# %%
data.hist(column='AWND', bins=15)
data.plot.scatter(x = 'AWND', y = 'TAVG', color ='darkred', alpha=0.3)

# %% [markdown]
# From looking at these plots, it seems like most of the avegare temp are between 0 and 100 and
# no any distinct relation can be found between these values, so we are better of dropping
# AWND since it has no co-relation with the average temp. and also most of the values are missing
#
# Lets find the total weather stations we have

# %%
data= data.drop(['AWND'], axis=1)
data['STATION'].unique()
# Out:
# array(['USW00013739', 'USC00369464', 'USC00366927'], dtype=object)

# %%
data.describe()
# Out:
#           LATITUDE    LONGITUDE    ELEVATION         PRCP         TAVG  \
# count  3399.000000  3399.000000  3399.000000  3331.000000  3261.000000
# mean     39.999387   -75.486684    57.681701     3.711333    53.549586
# std       0.096978     0.159928    47.469286     2.065311    19.027916
# min      39.873270   -75.635000     3.000000     0.020000   -84.900000
# 25%      39.970800   -75.635000    32.000000     2.245000    38.600000
# 50%      39.970800   -75.501100    32.000000     3.340000    53.900000
# 75%      40.120000   -75.501100   114.300000     4.810000    69.300000
# max      40.120000   -75.226780   114.300000    19.310000   185.900000
#
#               TMAX         TMIN
# count  3285.000000  3307.000000
# mean     63.490594    43.334986
# std      19.652024    18.414772
# min     -71.700000   -88.700000
# 25%      47.800000    29.600000
# 50%      65.100000    42.600000
# 75%      80.300000    58.200000
# max     201.400000   185.700000

# %% [markdown]
# looks like we have some missing values for PRCP, TAVG, TMAX and TMIN
# also looking at the decription there are some odd values for min TMAX, TMIN and TAVG and max TMAX, TMIN and TAV
# try to find out if we see some relation with the elevation and average temp. values
# finding the unique values for elevation

# %%
data['ELEVATION'].unique()
# Out:
# array([  3. , 114.3,  32. ])

# %% [markdown]
# see if we can find any relationship between elevation and average temp. readings

# %%
data.plot.scatter(x = 'TAVG', y = 'ELEVATION', color ='darkred', alpha=0.3)

# %% [markdown]
# Again we can't find any clear relationship between the temp. and elevation since the stations are not
# located in relatively different elevations from each other

# %%
data= data.drop(['ELEVATION'], axis=1)

# %% [markdown]
# We can identify the temp. readings using the STATION only so we don't really need the NAME, LATITUDE AND LOGITUDE columns here as well

# %%
toDrop = ['NAME', 'LATITUDE', 'LONGITUDE']
data = data.drop(toDrop, axis=1)

# %%
data
# Out:
#           STATION       DATE AWND_ATTRIBUTES  PRCP PRCP_ATTRIBUTES  TAVG  \
# 0     USW00013739 1948-01-01             NaN  4.69            ,,,X  25.9
# 1     USW00013739 1948-02-01             NaN  2.84            ,,,X  31.8
# 2     USW00013739 1948-03-01             NaN  3.76            ,,,X  43.8
# 3     USW00013739 1948-04-01             NaN  3.93            ,,,X  52.0
# 4     USW00013739 1948-05-01             NaN  7.41            ,,,0  61.9
# 5     USW00013739 1948-06-01             NaN  4.94            ,,,0  71.1
# 6     USW00013739 1948-07-01             NaN  1.90            ,,,0  76.4
# 7     USW00013739 1948-08-01             NaN  5.96            ,,,0  74.6
# 8     USW00013739 1948-09-01             NaN  2.09            ,,,0  67.7
# 9     USW00013739 1948-10-01             NaN  1.53            ,,,0  55.2
# 10    USW00013739 1948-11-01             NaN  4.79            ,,,0  50.9
# 11    USW00013739 1948-12-01             NaN  5.26            ,,,0  37.4
# 12    USW00013739 1949-01-01             NaN  6.06            ,,,0  39.8
# 13    USW00013739 1949-02-01             NaN  3.56            ,,,0  39.3
# 14    USW00013739 1949-03-01             NaN  2.78            ,,,0  43.9
# 15    USW00013739 1949-04-01             NaN  2.36            ,,,0  53.4
# 16    USW00013739 1949-05-01             NaN  5.91            ,,,0   NaN
# 17    USW00013739 1949-06-01             NaN  0.11            ,,,0  74.6
# 18    USW00013739 1949-07-01             NaN  4.25            ,,,0  80.2
# 19    USW00013739 1949-08-01             NaN  4.53            ,,,0  76.2
# 20    USW00013739 1949-09-01             NaN  4.10            ,,,0  65.6
# 21    USW00013739 1949-10-01             NaN  2.74            ,,,0  61.8
# 22    USW00013739 1949-11-01             NaN  1.09            ,,,0  45.8
# 23    USW00013739 1949-12-01             NaN  3.04            ,,,0  39.0
# 24    USW00013739 1950-01-01             NaN  1.85            ,,,0  43.3
# 25    USW00013739 1950-02-01             NaN  3.41            ,,,0  33.7
# 26    USW00013739 1950-03-01             NaN  4.69            ,,,0  38.6
# 27    USW00013739 1950-04-01             NaN  2.11            ,,,0  49.2
# 28    USW00013739 1950-05-01             NaN  3.89            ,,,0  61.0
# 29    USW00013739 1950-06-01             NaN  2.37            ,,,0  70.7
# ...           ...        ...             ...   ...             ...   ...
# 3369  USC00366927 2015-06-01             NaN  9.33            ,,,7   NaN
# 3370  USC00366927 2015-07-01             NaN  3.95            ,,,7  77.9
# 3371  USC00366927 2015-08-01             NaN  3.31           2,,,7  76.3
# 3372  USC00366927 2015-09-01             NaN  4.07            ,,,7   NaN
# 3373  USC00366927 2015-10-01             NaN  4.38           1,,,7  55.1
# 3374  USC00366927 2015-11-01             NaN  1.44            ,,,7  48.6
# 3375  USC00366927 2015-12-01             NaN  3.84           2,,,7  48.5
# 3376  USC00366927 2016-01-01             NaN  2.80           1,,,7  30.6
# 3377  USC00366927 2016-02-01             NaN  5.23           1,,,7  34.4
# 3378  USC00366927 2016-03-01             NaN  1.27           1,,,7  47.8
# 3379  USC00366927 2016-04-01             NaN  2.21           2,,,7   NaN
# 3380  USC00366927 2016-05-01             NaN  4.73            ,,,7  61.6
# 3381  USC00366927 2016-06-01             NaN  1.55            ,,,7  73.1
# 3382  USC00366927 2016-07-01             NaN  3.87           2,,,7  80.1
# 3383  USC00366927 2016-08-01             NaN  2.20            ,,,7  79.2
# 3384  USC00366927 2016-09-01             NaN  5.54            ,,,7  70.4
# 3385  USC00366927 2016-10-01             NaN  1.41            ,,,7  56.8
# 3386  USC00366927 2016-11-01             NaN  3.22            ,,,7  46.8
# 3387  USC00366927 2016-12-01             NaN  2.52           5,,,7  35.7
# 3388  USC00366927 2017-01-01             NaN  3.08           3,,,7  36.0
# 3389  USC00366927 2017-02-01             NaN  1.37           1,,,7  41.3
# 3390  USC00366927 2017-03-01             NaN  2.49           3,,,7  40.5
# 3391  USC00366927 2017-04-01             NaN  2.96            ,,,7  58.2
# 3392  USC00366927 2017-05-01             NaN  3.75           2,,,7  61.2
# 3393  USC00366927 2017-06-01             NaN  4.56           2,,,7  72.4
# 3394  USC00366927 2017-07-01             NaN  3.11           2,,,7  77.4
# 3395  USC00366927 2017-08-01             NaN  3.46            ,,,7  73.2
# 3396  USC00366927 2017-09-01             NaN  1.03           1,,,7  69.2
# 3397  USC00366927 2017-10-01             NaN  3.88            ,,,7  61.0
# 3398  USC00366927 2017-11-01             NaN  0.76           3,,,7  44.1
#
#      TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES
# 0                 ,X  32.8            ,,,X  19.1            ,,,X
# 1                 ,X  40.2            ,,,X  23.3            ,,,X
# 2                 ,X  54.5            ,,,X  33.2            ,,,X
# 3                 ,X  62.2            ,,,X  41.7            ,,,X
# 4                 ,0  71.3            ,,,0  52.5            ,,,0
# 5                 ,0  81.2            ,,,0  61.0            ,,,0
# 6                 ,0  85.9            ,,,0  66.8            ,,,0
# 7                 ,0  83.9            ,,,0  65.3            ,,,0
# 8                 ,0  78.4            ,,,0  57.0            ,,,0
# 9                 ,0  64.0            ,,,0  46.5            ,,,0
# 10                ,0  59.4            ,,,0  42.4            ,,,0
# 11                ,0  45.1            ,,,0  29.6            ,,,0
# 12                ,0  47.3            ,,,0  32.3            ,,,0
# 13                ,0  47.9            ,,,0  30.6            ,,,0
# 14                ,0  53.4            ,,,0  34.4            ,,,0
# 15                ,0  63.5            ,,,0  43.3            ,,,0
# 16                ,0  75.0            ,,,0  53.8            ,,,0
# 17                ,0  85.2            ,,,0  64.0            ,,,0
# 18                ,0  89.7            ,,,0  70.8            ,,,0
# 19                ,0  85.9            ,,,0  66.5            ,,,0
# 20                ,0  75.2            ,,,0  56.1            ,,,0
# 21                ,0  70.2            ,,,0  53.4            ,,,0
# 22                ,0  54.8            ,,,0  36.7            ,,,0
# 23                ,0  47.1            ,,,0  30.9            ,,,0
# 24                ,0  52.3            ,,,0  34.3            ,,,0
# 25                ,0  40.4            ,,,0  27.1            ,,,0
# 26                ,0  47.7            ,,,0  29.5            ,,,0
# 27                ,0  59.1            ,,,0  39.2            ,,,0
# 28                ,0  70.2            ,,,0  51.7            ,,,0
# 29                ,0  81.1            ,,,0  60.4            ,,,0
# ...              ...   ...             ...   ...             ...
# 3369             NaN   NaN             NaN  62.9            ,,,7
# 3370             5,7  88.6           5,,,7  67.2            ,,,7
# 3371             4,7  89.4           4,,,7  63.1           2,,,7
# 3372             NaN   NaN             NaN  58.7            ,,,7
# 3373             6,7  66.8           5,,,7  43.3           2,,,7
# 3374              ,7  60.5            ,,,7  36.7            ,,,7
# 3375              ,7  56.8            ,,,7  40.2            ,,,7
# 3376             3,7  40.5           1,,,7  20.7           3,,,7
# 3377             4,7  43.5           3,,,7  25.2           4,,,7
# 3378             1,7  61.0           1,,,7  34.7           1,,,7
# 3379             NaN   NaN             NaN  39.8           1,,,7
# 3380             4,7  72.5           4,,,7  50.8            ,,,7
# 3381             1,7  85.2           1,,,7  60.9           1,,,7
# 3382             2,7  91.7           2,,,7  68.4           2,,,7
# 3383              ,7  90.7            ,,,7  67.6            ,,,7
# 3384              ,7  82.7            ,,,7  58.2            ,,,7
# 3385             5,7  67.9           5,,,7  45.8            ,,,7
# 3386             1,7  59.5           1,,,7  34.1            ,,,7
# 3387             3,7  44.4           2,,,7  27.1           2,,,7
# 3388             2,7  43.2           1,,,7  28.9           2,,,7
# 3389             1,7  52.2           1,,,7  30.4           1,,,7
# 3390              ,7  49.8            ,,,7  31.1            ,,,7
# 3391              ,7  69.1            ,,,7  47.2            ,,,7
# 3392              ,7  71.0            ,,,7  51.5            ,,,7
# 3393             2,7  83.9           2,,,7  60.9           2,,,7
# 3394              ,7  87.1            ,,,7  67.7            ,,,7
# 3395              ,7  83.7            ,,,7  62.7            ,,,7
# 3396             1,7  80.5           1,,,7  57.9           1,,,7
# 3397              ,7  72.1            ,,,7  49.9            ,,,7
# 3398             3,7  55.9           3,,,7  32.4           3,,,7
#
# [3399 rows x 11 columns]

# %% [markdown]
# Lets also drop the attributes which are not of any significant help

# %%
attributes = ['AWND_ATTRIBUTES', 'PRCP_ATTRIBUTES', 'TAVG_ATTRIBUTES', 'TMAX_ATTRIBUTES', 'TMIN_ATTRIBUTES']
data = data.drop(attributes, axis =1)

# %%
data.head()
# Out:
#        STATION       DATE  PRCP  TAVG  TMAX  TMIN
# 0  USW00013739 1948-01-01  4.69  25.9  32.8  19.1
# 1  USW00013739 1948-02-01  2.84  31.8  40.2  23.3
# 2  USW00013739 1948-03-01  3.76  43.8  54.5  33.2
# 3  USW00013739 1948-04-01  3.93  52.0  62.2  41.7
# 4  USW00013739 1948-05-01  7.41  61.9  71.3  52.5

# %% [markdown]
# Our data looks pretty clean and we can add values to our cleaned table now

# %%
cleaned = data

# %%
cleaned.head()
# Out:
#        STATION       DATE  PRCP  TAVG  TMAX  TMIN
# 0  USW00013739 1948-01-01  4.69  25.9  32.8  19.1
# 1  USW00013739 1948-02-01  2.84  31.8  40.2  23.3
# 2  USW00013739 1948-03-01  3.76  43.8  54.5  33.2
# 3  USW00013739 1948-04-01  3.93  52.0  62.2  41.7
# 4  USW00013739 1948-05-01  7.41  61.9  71.3  52.5

# %% [markdown]
# Adding new columns to our new table

# %%
cleaned['NewTAVG'] = 'default'
cleaned['NewTMAX'] = 'default'
cleaned['NewTMIN'] = 'default'

# %%
cleaned = cleaned.sort_values(by='DATE', ascending=True)

# %% [markdown]
# We need to now average multiple temp. readings for each month
# since we have NaN values as well for the temp. readings,lets see if our average is being affected by
# NaN values

# %%
cleaned[cleaned['DATE'] == '2017-02-01']
# Out:
#           STATION       DATE  PRCP  TAVG  TMAX  TMIN  NewTAVG  NewTMAX  \
# 2195  USC00369464 2017-02-01  1.90  39.0  51.2  26.8  default  default
# 3389  USC00366927 2017-02-01  1.37  41.3  52.2  30.4  default  default
# 829   USW00013739 2017-02-01  1.30   NaN  53.5  34.9  default  default
#
#       NewTMIN
# 2195  default
# 3389  default
# 829   default

# %%
sum =0
mask = cleaned['DATE'] == '2017-02-01'
value = cleaned.loc[mask, 'TAVG']
sum = value.sum()

# %%
sum
# Out:
# 80.3

# %%
count = value.count()
count
# Out:
# 2

# %%
average = sum/count
average
# Out:
# 40.15

# %% [markdown]
# Here the NaN value is not counted while findind the average of those three readings for TAVG
# So looks like we don't have to worry for NaN values while finding the average

# %% [markdown]
# We also dont want to include the mistaken measurements in our average as well
#
# Lets see how many mistaken measurements are there in our data

# %% [markdown]
# Suppose range for correct values are only between -5 and 110 since the readings looks like to be in Fahrenheit.
# .We choose this range because the temperature beyond this range can be lethal for human beings. So if the readings show temperatures out of this range, those values must be miskenly measured.

# %%
cleaned[(cleaned['TAVG'] > 110) | (cleaned['TAVG'] < -5)]
# Out:
#           STATION       DATE   PRCP   TAVG  TMAX  TMIN  NewTAVG  NewTMAX  \
# 1059  USC00369464 1911-05-01   1.17  172.4  79.6  55.2  default  default
# 1113  USC00369464 1916-09-01   3.62  162.6  77.7  55.5  default  default
# 2290  USC00366927 1921-03-01   1.52  148.0  67.2  36.7  default  default
# 1237  USC00369464 1927-09-01   3.21  160.8  76.6  55.0  default  default
# 2409  USC00366927 1931-06-01   3.46  179.3  87.1  59.4  default  default
# 1284  USC00369464 1931-09-01   1.56  -33.8  79.3  63.0  default  default
# 1339  USC00369464 1936-05-01   2.12  -53.6  76.3  50.6  default  default
# 1444  USC00369464 1945-02-01   3.13  -84.9  40.8  25.4  default  default
# 1486  USC00369464 1948-08-01   4.11  -27.3  84.0  63.4  default  default
# 41    USW00013739 1951-06-01   4.18  -26.8  80.5  62.0  default  default
# 71    USW00013739 1953-12-01   4.28  -60.6  47.8   NaN  default  default
# 128   USW00013739 1958-09-01   2.55  159.9  76.7  55.2  default  default
# 1617  USC00369464 1959-11-01   3.39  -72.1  53.4  34.4  default  default
# 178   USW00013739 1962-11-01   4.60  142.0  51.3  32.8  default  default
# 2796  USC00366927 1963-11-01   6.52  163.2  58.4  36.0  default  default
# 1673  USC00369464 1964-07-01   4.06  -18.3  86.8  62.7  default  default
# 2837  USC00366927 1967-04-01   2.13  -45.0  66.8  39.1  default  default
# 245   USW00013739 1968-06-01   5.89  179.1  81.2  61.1  default  default
# 1761  USC00369464 1972-09-01   1.20  -47.3  77.7  53.8  default  default
# 371   USW00013739 1978-12-01   5.61  145.6  47.2  29.9  default  default
# 445   USW00013739 1985-02-01   2.44  139.3  43.9  26.6  default  default
# 3096  USC00366927 1989-02-01   2.87  139.3  40.0  22.7  default  default
# 526   USW00013739 1991-11-01   1.55  -61.8  55.0  39.5  default  default
# 541   USW00013739 1993-02-01   3.03  -80.1  40.2  23.6  default  default
# 581   USW00013739 1996-06-01   4.74  -27.0  82.0  64.0  default  default
# 2031  USC00369464 2003-06-01  12.47  185.9  78.4  57.4  default  default
# 721   USW00013739 2008-02-01   3.93  -77.1  45.4  28.3  default  default
# 742   USW00013739 2009-11-01   2.06  -57.1  57.8  44.0  default  default
# 2150  USC00369464 2013-05-01   3.92  161.6  72.6  48.6  default  default
#
#       NewTMIN
# 1059  default
# 1113  default
# 2290  default
# 1237  default
# 2409  default
# 1284  default
# 1339  default
# 1444  default
# 1486  default
# 41    default
# 71    default
# 128   default
# 1617  default
# 178   default
# 2796  default
# 1673  default
# 2837  default
# 245   default
# 1761  default
# 371   default
# 445   default
# 3096  default
# 526   default
# 541   default
# 581   default
# 2031  default
# 721   default
# 742   default
# 2150  default

# %%
cleaned[(cleaned['TMAX'] > 110) | (cleaned['TMAX'] < -5)]
# Out:
#           STATION       DATE  PRCP  TAVG   TMAX  TMIN  NewTAVG  NewTMAX  \
# 862   USC00369464 1894-11-01  2.78  40.9  -62.7  33.5  default  default
# 1097  USC00369464 1915-05-01   NaN  59.2  -31.4  48.9  default  default
# 2300  USC00366927 1922-01-01  1.91  26.0  137.1  17.0  default  default
# 2329  USC00366927 1924-07-01  3.14  73.1  -20.1  62.2  default  default
# 1299  USC00369464 1932-12-01  3.00  37.8  -53.7  30.3  default  default
# 1345  USC00369464 1936-11-01  1.13  41.9  -38.7  32.6  default  default
# 1415  USC00369464 1942-09-01  4.14  67.2  193.3  56.1  default  default
# 1476  USC00369464 1947-10-01  1.08  62.1  -44.7  50.0  default  default
# 2653  USC00366927 1951-12-01  4.43  35.7  -71.7  25.2  default  default
# 47    USW00013739 1951-12-01  5.49  38.6  152.7  30.6  default  default
# 1618  USC00369464 1959-12-01  4.94  37.6  -55.0  30.2  default  default
# 1639  USC00369464 1961-09-01  1.97  72.4  201.4  61.3  default  default
# 207   USW00013739 1965-04-01  2.33  49.0  -33.9  39.9  default  default
# 209   USW00013739 1965-06-01  2.85  70.0  -34.6  59.6  default  default
# 2838  USC00366927 1967-05-01  3.44  55.6  -25.5  43.7  default  default
# 2931  USC00366927 1975-03-01  4.59  41.3  150.0  31.7  default  default
# 2955  USC00366927 1977-03-01  6.02   NaN  -47.9  36.6  default  default
# 370   USW00013739 1978-11-01  2.20  47.9  -34.1  39.9  default  default
# 2989  USC00366927 1980-01-01  1.88  32.1  -58.4  24.6  default  default
# 389   USW00013739 1980-06-01  1.74  70.6  -11.4  59.7  default  default
# 596   USW00013739 1997-09-01  1.59  67.0  173.9  58.2  default  default
# 1991  USC00369464 2000-01-01  4.35  28.3  -64.5  17.2  default  default
# 665   USW00013739 2003-06-01  8.09  71.3  -23.3  62.9  default  default
# 3278  USC00366927 2007-07-01  4.22  76.5  -13.6  65.7  default  default
# 3320  USC00366927 2011-04-01  5.63  56.0  -43.6  44.6  default  default
# 3336  USC00366927 2012-09-01  3.18  66.8  194.2  54.4  default  default
# 2155  USC00369464 2013-10-01  5.21  55.7  -42.1  43.4  default  default
# 3350  USC00366927 2013-11-01  2.50  41.7  -37.2  30.6  default  default
# 2180  USC00369464 2015-11-01  1.80  47.4  -35.2  35.0  default  default
#
#       NewTMIN
# 862   default
# 1097  default
# 2300  default
# 2329  default
# 1299  default
# 1345  default
# 1415  default
# 1476  default
# 2653  default
# 47    default
# 1618  default
# 1639  default
# 207   default
# 209   default
# 2838  default
# 2931  default
# 2955  default
# 370   default
# 2989  default
# 389   default
# 596   default
# 1991  default
# 665   default
# 3278  default
# 3320  default
# 3336  default
# 2155  default
# 3350  default
# 2180  default

# %%
cleaned[(cleaned['TMAX'] > 110) | (cleaned['TMAX'] < -5)]
# Out:
#           STATION       DATE  PRCP  TAVG   TMAX  TMIN  NewTAVG  NewTMAX  \
# 862   USC00369464 1894-11-01  2.78  40.9  -62.7  33.5  default  default
# 1097  USC00369464 1915-05-01   NaN  59.2  -31.4  48.9  default  default
# 2300  USC00366927 1922-01-01  1.91  26.0  137.1  17.0  default  default
# 2329  USC00366927 1924-07-01  3.14  73.1  -20.1  62.2  default  default
# 1299  USC00369464 1932-12-01  3.00  37.8  -53.7  30.3  default  default
# 1345  USC00369464 1936-11-01  1.13  41.9  -38.7  32.6  default  default
# 1415  USC00369464 1942-09-01  4.14  67.2  193.3  56.1  default  default
# 1476  USC00369464 1947-10-01  1.08  62.1  -44.7  50.0  default  default
# 2653  USC00366927 1951-12-01  4.43  35.7  -71.7  25.2  default  default
# 47    USW00013739 1951-12-01  5.49  38.6  152.7  30.6  default  default
# 1618  USC00369464 1959-12-01  4.94  37.6  -55.0  30.2  default  default
# 1639  USC00369464 1961-09-01  1.97  72.4  201.4  61.3  default  default
# 207   USW00013739 1965-04-01  2.33  49.0  -33.9  39.9  default  default
# 209   USW00013739 1965-06-01  2.85  70.0  -34.6  59.6  default  default
# 2838  USC00366927 1967-05-01  3.44  55.6  -25.5  43.7  default  default
# 2931  USC00366927 1975-03-01  4.59  41.3  150.0  31.7  default  default
# 2955  USC00366927 1977-03-01  6.02   NaN  -47.9  36.6  default  default
# 370   USW00013739 1978-11-01  2.20  47.9  -34.1  39.9  default  default
# 2989  USC00366927 1980-01-01  1.88  32.1  -58.4  24.6  default  default
# 389   USW00013739 1980-06-01  1.74  70.6  -11.4  59.7  default  default
# 596   USW00013739 1997-09-01  1.59  67.0  173.9  58.2  default  default
# 1991  USC00369464 2000-01-01  4.35  28.3  -64.5  17.2  default  default
# 665   USW00013739 2003-06-01  8.09  71.3  -23.3  62.9  default  default
# 3278  USC00366927 2007-07-01  4.22  76.5  -13.6  65.7  default  default
# 3320  USC00366927 2011-04-01  5.63  56.0  -43.6  44.6  default  default
# 3336  USC00366927 2012-09-01  3.18  66.8  194.2  54.4  default  default
# 2155  USC00369464 2013-10-01  5.21  55.7  -42.1  43.4  default  default
# 3350  USC00366927 2013-11-01  2.50  41.7  -37.2  30.6  default  default
# 2180  USC00369464 2015-11-01  1.80  47.4  -35.2  35.0  default  default
#
#       NewTMIN
# 862   default
# 1097  default
# 2300  default
# 2329  default
# 1299  default
# 1345  default
# 1415  default
# 1476  default
# 2653  default
# 47    default
# 1618  default
# 1639  default
# 207   default
# 209   default
# 2838  default
# 2931  default
# 2955  default
# 370   default
# 2989  default
# 389   default
# 596   default
# 1991  default
# 665   default
# 3278  default
# 3320  default
# 3336  default
# 2155  default
# 3350  default
# 2180  default

# %% [markdown]
# Looks like we have a plenty of mistaken measurements. Since we don't want to include these values in our
# average, we can simply replace them with NaN values so that they don't get treated as a value
# during average calculation
#
# Create new table for removing the mistaken measurements.

# %%
newDf = pd.DataFrame(columns=['TAVG', 'TMAX', 'TMIN'])

# %%
newDf['TAVG'] = cleaned['TAVG']
newDf['TMAX'] = cleaned['TMAX']
newDf['TMIN'] = cleaned['TMIN']

# %%
newDf.head()
# Out:
#       TAVG  TMAX  TMIN
# 2198  21.1  30.0  12.3
# 841   21.3  28.5  14.1
# 2199  30.9  38.7  23.2
# 842   30.2  38.0 -84.7
# 843   51.7  61.7 -68.2

# %% [markdown]
# Replace all the mistaken measurements with NaN values

# %%
newDf.mask((newDf > 110) | (newDf < -5), inplace=True)

# %% [markdown]
# Check if the mistaken values are gone

# %%
newDf[(newDf['TMAX'] > 110) | (newDf['TMAX'] < -5)]
# Out:
# Empty DataFrame
# Columns: [TAVG, TMAX, TMIN]
# Index: []

# %%
newDf[(newDf['TAVG'] > 110) | (newDf['TAVG'] < -5)]
# Out:
# Empty DataFrame
# Columns: [TAVG, TMAX, TMIN]
# Index: []

# %%
newDf[(newDf['TMIN'] > 110) | (newDf['TMIN'] < -5)]
# Out:
# Empty DataFrame
# Columns: [TAVG, TMAX, TMIN]
# Index: []

# %%
newDf.head()
# Out:
#       TAVG  TMAX  TMIN
# 2198  21.1  30.0  12.3
# 841   21.3  28.5  14.1
# 2199  30.9  38.7  23.2
# 842   30.2  38.0   NaN
# 843   51.7  61.7   NaN

# %% [markdown]
# We have replaced all the mistaken values with NaN so it wont affect our average calculations.
#
# Now, copy our temperature columns from newDf to cleaned

# %%
cleaned['TAVG'] = newDf['TAVG']
cleaned['TMAX'] = newDf['TMAX']
cleaned['TMIN'] = newDf['TMIN']

# %%
cleaned.head()
# Out:
#           STATION       DATE  PRCP  TAVG  TMAX  TMIN  NewTAVG  NewTMAX  \
# 2198  USC00366927 1893-01-01  2.62  21.1  30.0  12.3  default  default
# 841   USC00369464 1893-01-01   NaN  21.3  28.5  14.1  default  default
# 2199  USC00366927 1893-02-01  5.54  30.9  38.7  23.2  default  default
# 842   USC00369464 1893-02-01  6.13  30.2  38.0   NaN  default  default
# 843   USC00369464 1893-04-01  5.02  51.7  61.7   NaN  default  default
#
#       NewTMIN
# 2198  default
# 841   default
# 2199  default
# 842   default
# 843   default

# %%
uniqueDate = cleaned['DATE'].unique()

# %%
type(uniqueDate)
# Out:
# numpy.ndarray

# %%
uniqueDate
# Out:
# array(['1893-01-01T00:00:00.000000000', '1893-02-01T00:00:00.000000000',
#        '1893-04-01T00:00:00.000000000', ...,
#        '2017-11-01T00:00:00.000000000', '2017-12-01T00:00:00.000000000',
#        '2018-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# Creating table for TAVG, TMAX and TMIN values

# %%
TAVG_arr = []

for i in uniqueDate:
    
    mask = cleaned['DATE'] == i
    value = cleaned.loc[mask, 'TAVG']
    sum = value.sum()
    count= value.count()
    average = sum/count
    
    TAVG_arr.append([i, sum, count, average])
# Out:
# /home/kratos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':

# %%
TAVGtable = pd.DataFrame()
TAVGtable = pd.DataFrame(TAVG_arr)
TAVGtable.columns= ['DATE','SUM', 'COUNT', 'AVERAGE']

# %%
TMAX_arr = []

for i in uniqueDate:
    
    mask = cleaned['DATE'] == i
    value = cleaned.loc[mask, 'TMAX']
    sum = value.sum()
    count= value.count()
    average = sum/count
    
    TMAX_arr.append([i, sum, count, average])
    
TMAXtable = pd.DataFrame()
TMAXtable = pd.DataFrame(TMAX_arr)
TMAXtable.columns= ['DATE','SUM', 'COUNT', 'AVERAGE']
# Out:
# /home/kratos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':

# %%
TMIN_arr = []

for i in uniqueDate:
    
    mask = cleaned['DATE'] == i
    value = cleaned.loc[mask, 'TMIN']
    sum = value.sum()
    count= value.count()
    average = sum/count
    
    TMIN_arr.append([i, sum, count, average])
    
TMINtable = pd.DataFrame()
TMINtable = pd.DataFrame(TMIN_arr)
TMINtable.columns= ['DATE','SUM', 'COUNT', 'AVERAGE']
# Out:
# /home/kratos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':

# %%
# lets add more columns to our TAVGtable 
TAVGtable['TMAX_AVERAGE'] = TMAXtable['AVERAGE']

# %%
TAVGtable.head()
# Out:
#         DATE   SUM  COUNT  AVERAGE  TMAX_AVERAGE
# 0 1893-01-01  42.4      2    21.20         29.25
# 1 1893-02-01  61.1      2    30.55         38.35
# 2 1893-04-01  51.7      1    51.70         61.70
# 3 1893-05-01  59.5      1    59.50         69.00
# 4 1893-06-01  70.8      1    70.80         79.70

# %%
TAVGtable['TMIN_AVERAGE'] = TMINtable['AVERAGE']

# %%
TAVGtable.columns = ['DATE','SUM','COUNT','TAVG_AVERAGE','TMAX_AVERAGE','TMIN_AVERAGE']

# %%
TAVGtable.isnull().values.sum()
# Out:
# 35

# %% [markdown]
# Looks like we still have 35 rows with null values in them.
# Since it represents around 2.3% of the whole data which is not a significant amount to skew our data
# ,we are better off dropping these rows from our data

# %%
TAVGtable = TAVGtable.dropna()

# %%
TAVGtable.isnull().values.any()
# Out:
# False

# %%
TAVGtable.head()
# Out:
#         DATE   SUM  COUNT  TAVG_AVERAGE  TMAX_AVERAGE  TMIN_AVERAGE
# 0 1893-01-01  42.4      2         21.20         29.25          13.2
# 1 1893-02-01  61.1      2         30.55         38.35          23.2
# 3 1893-05-01  59.5      1         59.50         69.00          50.0
# 4 1893-06-01  70.8      1         70.80         79.70          61.9
# 5 1893-07-01  74.4      1         74.40         83.50          65.3

# %%
FinalTable = TAVGtable.drop(['SUM','COUNT'], axis=1)

# %%
FinalTable.head()
# Out:
#         DATE  TAVG_AVERAGE  TMAX_AVERAGE  TMIN_AVERAGE
# 0 1893-01-01         21.20         29.25          13.2
# 1 1893-02-01         30.55         38.35          23.2
# 3 1893-05-01         59.50         69.00          50.0
# 4 1893-06-01         70.80         79.70          61.9
# 5 1893-07-01         74.40         83.50          65.3

# %% [markdown]
# So our final data looks like this and we are ready to plot it

# %%
plt.plot(FinalTable['DATE'], FinalTable['TAVG_AVERAGE'], '*')
plt.xticks(rotation='vertical')
# Out:
# (array([686291., 693596., 700900., 708205., 715510., 722815., 730120.,
#         737425., 744730.]), <a list of 9 Text xticklabel objects>)

# %%
plt.plot(FinalTable['DATE'], FinalTable['TMAX_AVERAGE'], '*')
plt.xticks(rotation='vertical')
# Out:
# (array([686291., 693596., 700900., 708205., 715510., 722815., 730120.,
#         737425., 744730.]), <a list of 9 Text xticklabel objects>)

# %%
plt.plot(FinalTable['DATE'], FinalTable['TMIN_AVERAGE'], '*')
plt.xticks(rotation='vertical')
# Out:
# (array([686291., 693596., 700900., 708205., 715510., 722815., 730120.,
#         737425., 744730.]), <a list of 9 Text xticklabel objects>)

# %%
FinalTable.set_index('DATE')['TAVG_AVERAGE'].plot()

# %%
FinalTable.set_index('DATE')['TMAX_AVERAGE'].plot()

# %%
FinalTable.set_index('DATE')['TMIN_AVERAGE'].plot();

# %% [markdown]
# We can visualize our data but still it is a little hard to figure out how the temp. values are
# evolving across time
# . Lets plot according to the monthly average values so it will be easier to figure out the change

# %%
# we already have our cleaned data in cleaned table
cleaned.head()
# Out:
#           STATION       DATE  PRCP  TAVG  TMAX  TMIN  NewTAVG  NewTMAX  \
# 2198  USC00366927 1893-01-01  2.62  21.1  30.0  12.3  default  default
# 841   USC00369464 1893-01-01   NaN  21.3  28.5  14.1  default  default
# 2199  USC00366927 1893-02-01  5.54  30.9  38.7  23.2  default  default
# 842   USC00369464 1893-02-01  6.13  30.2  38.0   NaN  default  default
# 843   USC00369464 1893-04-01  5.02  51.7  61.7   NaN  default  default
#
#       NewTMIN
# 2198  default
# 841   default
# 2199  default
# 842   default
# 843   default

# %%
# checking how we can get the month values for each date

cleaned['DATE'].dt.month == 5
# Out:
# 2198    False
# 841     False
# 2199    False
# 842     False
# 843     False
# 844      True
# 845     False
# 846     False
# 847     False
# 848     False
# 849     False
# 850     False
# 851     False
# 852     False
# 2200    False
# 2201    False
# 853     False
# 2202    False
# 854     False
# 855     False
# 2203    False
# 856      True
# 2204     True
# 2205    False
# 857     False
# 2206    False
# 858     False
# 2207    False
# 859     False
# 2208    False
#         ...
# 827     False
# 2193    False
# 3388    False
# 2194    False
# 828     False
# 2195    False
# 3389    False
# 829     False
# 2196    False
# 3390    False
# 830     False
# 2197    False
# 3391    False
# 831     False
# 832      True
# 3392     True
# 833     False
# 3393    False
# 3394    False
# 834     False
# 835     False
# 3395    False
# 836     False
# 3396    False
# 3397    False
# 837     False
# 838     False
# 3398    False
# 839     False
# 840     False
# Name: DATE, Length: 3399, dtype: bool

# %% [markdown]
# Putting the months and their average values in seperate table and we do it for TAVG,TMAX and TMIN

# %%
arrayTAVG = []
arrayTMAX = []
arrayTMIN = []

for i in range(1, 13):
    
    mask = cleaned['DATE'].dt.month == i
    
    value1 = cleaned.loc[mask, 'TAVG']
    value2 = cleaned.loc[mask, 'TMAX']
    value3 = cleaned.loc[mask, 'TMIN']
    
    average1 = value1.sum()/value1.count()
    average2 = value2.sum()/value2.count()
    average3 = value3.sum()/value3.count()
    
    arrayTAVG.append([i, average1])
    arrayTMAX.append([i, average2])
    arrayTMIN.append([i, average3])

arrayTAVG
# Out:
# [[1, 31.116363636363637],
#  [2, 32.60989010989011],
#  [3, 41.48754716981132],
#  [4, 52.13832116788321],
#  [5, 62.247565543071154],
#  [6, 71.12723880597014],
#  [7, 75.81213235294118],
#  [8, 74.02075471698113],
#  [9, 67.18154981549814],
#  [10, 55.72952029520295],
#  [11, 45.10230769230769],
#  [12, 34.927306273062726]]

# %% [markdown]
# We have all of our monthly average data so now we can add it to our new table

# %%
myData = pd.DataFrame(columns=["Month", "TAVG_average","TMAX_average", "TMIN_average"])
myData["Month"] = [arrayTAVG[i][0] for i in range(12)]
myData["TAVG_average"] = [arrayTAVG[i][1] for i in range(12)]
myData["TMAX_average"] = [arrayTMAX[i][1] for i in range(12)]
myData["TMIN_average"] = [arrayTMIN[i][1] for i in range(12)]

# %%
myData
# Out:
#     Month  TAVG_average  TMAX_average  TMIN_average
# 0       1     31.116364     39.830627     22.530292
# 1       2     32.609890     41.924820     23.507885
# 2       3     41.487547     51.803309     31.237868
# 3       4     52.138321     63.655720     40.651449
# 4       5     62.247566     73.930515     50.706204
# 5       6     71.127239     82.253731     60.054745
# 6       7     75.812132     86.436900     65.078545
# 7       8     74.020755     84.582721     63.373801
# 8       9     67.181550     78.039273     56.268953
# 9      10     55.729520     66.795956     44.601852
# 10     11     45.102308     55.040684     35.220974
# 11     12     34.927306     43.423985     26.434572

# %%
myData.set_index('Month')['TMIN_average'].plot();

# %% [markdown]
# Hmm, looks like we can now see the changes in temp. more clearly

# %% [markdown]
# Lets plot our final graph using all the average monthly values
# # Final Graph:

# %%
tempGraph = myData.set_index('Month').plot(figsize=(10,5), grid=True)
tempGraph.set_ylabel("Fahrenheit")
# Out:
# Text(0, 0.5, 'Fahrenheit')
